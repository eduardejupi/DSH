# %% [markdown]
# # Task
# Estrai i dati dei primi 12 pazienti dal file "dataset_1.zip" situato nella cartella "lab 1" all'interno della sezione "Condivisi con me" del mio Google Drive.

# %% [markdown]
# ## Monta google drive
#
# ### Subtask:
# Monta Google Drive per accedere ai file memorizzati.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access files stored in the user's Drive.

# %%
# Clean reinstall of compatible versions
# !pip uninstall -y numpy SimpleITK PyWavelets pyradiomics
# !pip install numpy==1.26.4 SimpleITK==2.3.1 PyWavelets==1.6.0

# !pip install git+https://github.com/AIM-Harvard/pyradiomics.git
# restart session
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: SimpleITK 2.3.1
# Uninstalling SimpleITK-2.3.1:
#   Successfully uninstalled SimpleITK-2.3.1
# Found existing installation: PyWavelets 1.6.0
# Uninstalling PyWavelets-1.6.0:
#   Successfully uninstalled PyWavelets-1.6.0
# Found existing installation: pyradiomics 3.1.1.dev111+g8ed579383
# Uninstalling pyradiomics-3.1.1.dev111+g8ed579383:
#   Successfully uninstalled pyradiomics-3.1.1.dev111+g8ed579383
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached SimpleITK-2.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# ...
#   Using cached pywavelets-1.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip uninstall -y numpy simpleITK
# !pip install numpy==1.26.4
# !pip install SimpleITK==2.3.1
import numpy
print("NumPy:", numpy.__version__)
print("SimpleITK:", SimpleITK.Version_VersionString())
# Out:
# Found existing installation: numpy 2.3.5
# Uninstalling numpy-2.3.5:
#   Successfully uninstalled numpy-2.3.5
# Found existing installation: simpleitk 2.5.3
# Uninstalling simpleitk-2.5.3:
#   Successfully uninstalled simpleitk-2.5.3
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyradiomics 3.1.1.dev111+g8ed579383 requires SimpleITK>=2.4.0, which is not installed.
# pyradiomics 3.1.1.dev111+g8ed579383 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
#
import numpy, SimpleITK, radiomics
from radiomics import featureextractor
print("NumPy:", numpy.__version__)
print("SimpleITK:", SimpleITK.Version_VersionString())
print("PyRadiomics:", radiomics.__version__)
# Out:
# NumPy: 1.26.4
# SimpleITK: 2.3.1
# PyRadiomics: 3.1.1.dev111+g8ed579383

# %%
import glob, os
ids = [
    15, 20, 35, 47, 49, 50, 51, 52, 54, 55, 56, 57, 60, 71, 77, 81,
    82, 83, 84, 85, 92, 101, 105, 112, 113, 115, 116, 120, 126, 127,
    132, 133, 135, 137, 139, 142, 143, 147, 148, 150, 152, 154
]

imgs  = sorted(glob.glob("/content/drive/MyDrive/DSH - Lab/Dataset_1/Immagini/image_*.nii.gz"))
masks = sorted(glob.glob("/content/drive/MyDrive/DSH - Lab/Dataset_1/Maschere/mask_*.nii.gz"))

# select only the images in TS
imgs = [i for i in imgs if int(os.path.basename(i).split("_")[1].split(".")[0]) in ids]
masks = [m for m in masks if int(os.path.basename(m).split("_")[1].split(".")[0]) in ids]

print("Immagini:", len(imgs))
print("Maschere:", len(masks))
print("Esempio immagini:", [os.path.basename(i) for i in imgs])
print("Esempio maschere:", [os.path.basename(m) for m in masks])
# Out:
# Immagini: 42
# Maschere: 42
# Esempio immagini: ['image_101.nii.gz', 'image_105.nii.gz', 'image_112.nii.gz', 'image_113.nii.gz', 'image_115.nii.gz', 'image_116.nii.gz', 'image_120.nii.gz', 'image_126.nii.gz', 'image_127.nii.gz', 'image_132.nii.gz', 'image_133.nii.gz', 'image_135.nii.gz', 'image_137.nii.gz', 'image_139.nii.gz', 'image_142.nii.gz', 'image_143.nii.gz', 'image_147.nii.gz', 'image_148.nii.gz', 'image_15.nii.gz', 'image_150.nii.gz', 'image_152.nii.gz', 'image_154.nii.gz', 'image_20.nii.gz', 'image_35.nii.gz', 'image_47.nii.gz', 'image_49.nii.gz', 'image_50.nii.gz', 'image_51.nii.gz', 'image_52.nii.gz', 'image_54.nii.gz', 'image_55.nii.gz', 'image_56.nii.gz', 'image_57.nii.gz', 'image_60.nii.gz', 'image_71.nii.gz', 'image_77.nii.gz', 'image_81.nii.gz', 'image_82.nii.gz', 'image_83.nii.gz', 'image_84.nii.gz', 'image_85.nii.gz', 'image_92.nii.gz']
# ...

# %%
import os, glob, re, pandas as pd
from radiomics import featureextractor

ids = [
    15, 20, 35, 47, 49, 50, 51, 52, 54, 55, 56, 57, 60, 71, 77, 81,
    82, 83, 84, 85, 92, 101, 105, 112, 113, 115, 116, 120, 126, 127,
    132, 133, 135, 137, 139, 142, 143, 147, 148, 150, 152, 154
]

IN_DIR = "/content/drive/MyDrive/DSH - Lab/Dataset_1/Immagini"
MASK_DIR = "/content/drive/MyDrive/DSH - Lab/Dataset_1/Maschere"
PARAMS = "/content/drive/MyDrive/DSH - Lab/Lab2/params.yaml"

# Inizializza l’estrattore (legge params.yaml)
extractor = featureextractor.RadiomicsFeatureExtractor(PARAMS)

rows = []
# Ordina per id numerico
mask_paths = sorted(
    glob.glob(os.path.join(MASK_DIR, "mask_*.nii.gz")),
    key=lambda p: int(re.findall(r"\d+", os.path.basename(p))[0])
)

for mask_path in mask_paths:
    k = int(re.findall(r"\d+", os.path.basename(mask_path))[0])
    if k not in ids:
        continue

    img_path = os.path.join(IN_DIR, f"image_{k}.nii.gz")
    if not os.path.exists(img_path):
        print(f"Salto ID {k}: immagine non trovata")
        continue

    result = extractor.execute(img_path, mask_path)
    # Tieni solo le feature (escludi diagnosi/diagnostics)
    feats = {k2: v2 for k2, v2 in result.items() if not k2.startswith("diagnostics")}
    feats["ID"] = k
    rows.append(feats)

df_feats = pd.DataFrame(rows).sort_values("ID").reset_index(drop=True)

# Reorder columns to put 'ID' first
cols = df_feats.columns.tolist()
cols.insert(0, cols.pop(cols.index('ID')))
df_feats = df_feats[cols]

df_feats.to_csv("/content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv", index=False)
print("✅ Salvato: /content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv")
display(df_feats.head())
# Out:
# INFO:radiomics.featureextractor:Loading parameter file /content/drive/MyDrive/DSH - Lab/Lab2/params.yaml
# INFO:radiomics.featureextractor:Calculating features with label: 1
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Computing shape
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING:radiomics.glcm:GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Computing ngtdm
# ...

# %%
df_feats.to_csv("/content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv", index=False)
print("✅ Salvato: /content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv")
display(df_feats.head())
# Out:
# ✅ Salvato: /content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv
#    ID  original_shape_Elongation  original_shape_Flatness  \
# 0  15                   0.574372                 0.134120
# 1  20                   0.793768                 0.453983
# 2  35                   0.256210                 0.160022
# 3  47                   0.771900                 0.428765
# 4  49                   0.606758                 0.308593
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        4.083645                       30.447595
# 1                       14.442899                       31.813735
# 2                        5.237948                       32.732676
# 3                       17.381763                       40.539115
# 4                       34.037420                      110.298691
#
#   original_shape_Maximum2DDiameterColumn original_shape_Maximum2DDiameterRow  \
# ...

# %%
from google.colab import auth
import gspread
from google.auth import default

# Authenticate to Google Drive and Google Sheets
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Open the spreadsheet and select the worksheet
try:
    spreadsheet = gc.open("Diagnosi")
    worksheet = spreadsheet.get_worksheet(0)
    # Get all data from the worksheet
    diagnosis_data = worksheet.get_all_records()
    df_diagnosis = pd.DataFrame(diagnosis_data)
    print("✅ Caricato il file Diagnosi.gsheet")
    display(df_diagnosis.head())
except Exception as e:
    print(f"Error loading Google Sheet: {e}")
    df_diagnosis = None
# Out:
# ✅ Caricato il file Diagnosi.gsheet
#   CASE NUMBER SEX AGE DEFINITIVE DIAGNOSIS  CHALLENGING CASES  \
# 0           1   F  59                     0                 1
# 1           2   M  74                     0                 1
# 2           3   M  65                     0                 0
# 3           4   M  73                     0                 0
# 4           5   F  88                     0                 0
#
#   CANCER AND DIVERTICULA
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0

# %%
if df_diagnosis is not None:
    # Rename 'CASE NUMBER' to 'ID' for merging
    df_diagnosis = df_diagnosis.rename(columns={"CASE NUMBER": "ID"})

    # Select only the relevant columns and rename 'DEFINITIVE DIAGNOSIS' to 'class'
    df_diagnosis = df_diagnosis[['ID', 'DEFINITIVE DIAGNOSIS ']].rename(columns={'DEFINITIVE DIAGNOSIS': 'class'})

    # Ensure 'ID' column is of the same type in both dataframes for merging
    #df_diagnosis['ID'] = df_diagnosis['ID'].astype(str)
    #df_feats['ID'] = df_feats['ID'].astype(str)

    # Merge the dataframes
    df_merged = pd.merge(df_feats, df_diagnosis, on='ID', how='left')

    # Save the merged dataframe
    output_csv_path_merged = "/content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv"
    df_merged.to_csv(output_csv_path_merged, index=False)

    print(f"✅ Salvato il file unito con la colonna 'class': {output_csv_path_merged}")
    display(df_merged.head())
else:
    print("Skipping merge as diagnosis data could not be loaded.")
# Out:
# ✅ Salvato il file unito con la colonna 'class': /content/drive/MyDrive/DSH - Lab/Lab2/features_TS.csv
#    ID  original_shape_Elongation  original_shape_Flatness  \
# 0  15                   0.574372                 0.134120
# 1  20                   0.793768                 0.453983
# 2  35                   0.256210                 0.160022
# 3  47                   0.771900                 0.428765
# 4  49                   0.606758                 0.308593
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        4.083645                       30.447595
# 1                       14.442899                       31.813735
# 2                        5.237948                       32.732676
# 3                       17.381763                       40.539115
# 4                       34.037420                      110.298691
#
#   original_shape_Maximum2DDiameterColumn original_shape_Maximum2DDiameterRow  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd # Import pandas if not already imported

if df_merged is not None:
    # Separate features and the class column
    features = df_merged.drop(columns=['ID', 'DEFINITIVE DIAGNOSIS ']) # Dropping the original class column as well
    class_col = df_merged[['ID', 'DEFINITIVE DIAGNOSIS ']].rename(columns={'DEFINITIVE DIAGNOSIS ': 'class'})

    # Min-Max Scaling
    scaler_minmax = MinMaxScaler()
    features_normalized = scaler_minmax.fit_transform(features)
    df_normalized = pd.DataFrame(features_normalized, columns=features.columns)
    df_normalized = pd.concat([class_col, df_normalized], axis=1) # Add ID and class back

    # Reorder columns for df_normalized
    cols_normalized = df_normalized.columns.tolist()
    cols_normalized.insert(0, cols_normalized.pop(cols_normalized.index('ID')))
    cols_normalized.append(cols_normalized.pop(cols_normalized.index('class')))
    df_normalized = df_normalized[cols_normalized]


    # Z-score Standardization
    scaler_zscore = StandardScaler()
    features_standardized = scaler_zscore.fit_transform(features)
    df_standardized = pd.DataFrame(features_standardized, columns=features.columns)
    df_standardized = pd.concat([class_col, df_standardized], axis=1) # Add ID and class back

    # Reorder columns for df_standardized
    cols_standardized = df_standardized.columns.tolist()
    cols_standardized.insert(0, cols_standardized.pop(cols_standardized.index('ID')))
    cols_standardized.append(cols_standardized.pop(cols_standardized.index('class')))
    df_standardized = df_standardized[cols_standardized]


    # Save to CSV files
    output_csv_path_normalized = "/content/drive/MyDrive/DSH - Lab/Lab2/features_TS_normalized.csv"
    df_normalized.to_csv(output_csv_path_normalized, index=False)
    print(f"✅ Salvato il file normalizzato: {output_csv_path_normalized}")

    output_csv_path_standardized = "/content/drive/MyDrive/DSH - Lab/Lab2/features_TS_standardized.csv"
    df_standardized.to_csv(output_csv_path_standardized, index=False)
    print(f"✅ Salvato il file standardizzato: {output_csv_path_standardized}")

else:
    print("Skipping scaling and saving as merged data could not be loaded.")
# Out:
# ✅ Salvato il file normalizzato: /content/drive/MyDrive/DSH - Lab/Lab2/features_TS_normalized.csv
# ✅ Salvato il file standardizzato: /content/drive/MyDrive/DSH - Lab/Lab2/features_TS_standardized.csv
